# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import requests

from selenium.webdriver.common.by import By

# %% [markdown]
# Question-1

# %%
driver=webdriver.Chrome()

# %%
driver.get(("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"))

# %%
Rank = []
Name = []
Artist = []
Date = []
Views = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append("-")

# %%
result = pd.DataFrame({})
result['Rank'] = Rank
result['Name'] = Name
result['Artist'] = Artist
result['Upload Date'] = Date
result['Views (in Billions)'] = Views

result
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[6]
# 1    2.                                   "Despacito"[9]
# 2    3.                       "Johny Johny Yes Papa"[17]
# 3    4.                                  "Bath Song"[18]
# 4    5.                               "Shape of You"[19]
# 5    6.                              "See You Again"[22]
# 6    7.                          "Wheels on the Bus"[27]
# 7    8.                "Phonics Song with Two Words"[28]
# 8    9.                                "Uptown Funk"[29]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[30]
# 10  11.                              "Gangnam Style"[31]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[36]
# 12  13.                             "Dame Tu Cosita"[37]
# 13  14.                                     "Axel F"[38]
# 14  15.                                      "Sugar"[39]
# ...

# %% [markdown]
# Question-2

# %%
driver=webdriver.Chrome()

# %%
driver.get(("https://www.bcci.tv/"))

# %%
inter=driver.find_element(By.XPATH,"/html/body/header/div[3]/ul/li[1]/button")
inter.click()

# %%
fixt=driver.find_element(By.XPATH,"/html/body/header/div[3]/div[1]/ul/div[1]/a[2]")
fixt.click()

# %%
Series=[]
Place=[]
Date=[]
Time=[]

# %%
try:
    for i in driver.find_elements(By.XPATH,"//h5[@class='match-tournament-name ng-binding']"):
        Series.append(i.text)
except NoSuchElementException:
    Series.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']"):
        Place.append(i.text)
except NoSuchElementException:
    Place.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='match-dates ng-binding']"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='match-time no-margin ng-binding']"):
        Time.append(i.text)
except NoSuchElementException:
    Time.append("-")

# %%
fixture = pd.DataFrame({})
fixture['Series'] = Series
fixture['Place'] = Place
fixture['Date'] = Date
fixture['Time'] = Time


fixture
# Out:
#                                       Series  \
# 0  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 1  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 2            AUSTRALIA TOUR OF INDIA 2023-24
# 3  ENGLAND A WOMENS TOUR OF INDIA T20 SERIES
# 4            AUSTRALIA TOUR OF INDIA 2023-24
# 5        ENGLAND WOMEN TOUR OF INDIA 2023-24
# 6        ENGLAND WOMEN TOUR OF INDIA 2023-24
# 7        ENGLAND WOMEN TOUR OF INDIA 2023-24
# 8         INDIA TOUR OF SOUTH AFRICA 2023-24
#
#                                                Place               Date  \
# 0                                  Wankhede Stadium,  29 NOVEMBER, 2023
# 1                                  Wankhede Stadium,   1 DECEMBER, 2023
# 2  Shaheed Veer Narayan Singh International Crick...   1 DECEMBER, 2023
# 3                                  Wankhede Stadium,   3 DECEMBER, 2023
# 4                             M Chinnaswamy Stadium,   3 DECEMBER, 2023
# 5                                  Wankhede Stadium,   6 DECEMBER, 2023
# ...

# %% [markdown]
# Question-3

# %%
driver=webdriver.Chrome()

# %%
driver.get(("http://statisticstimes.com/"))

# %%
eco=driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/button")
eco.click()

# %%
india=driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]")
india.click()

# %%
GDP = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
GDP.click()

# %%
Rank = []
State = []
GSDP1 = []
Share = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("-")


try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("-")

# %%
GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP1'] = GSDP1
GDP['Share'] = Share
GDP
# Out:
#    Rank                      State      GSDP1   Share
# 0     1                Maharashtra          -  13.94%
# 1     2                 Tamil Nadu  1,845,853   8.63%
# 2     3              Uttar Pradesh  1,687,818   8.39%
# 3     4                    Gujarat          -   7.96%
# 4     5                  Karnataka  1,631,977   7.91%
# ..  ...                        ...        ...     ...
# 61   29                     Sikkim     28,391   0.15%
# 62   30                   Nagaland          -   0.15%
# 63   31          Arunachal Pradesh          -   0.13%
# 64   32                    Mizoram     24,424   0.13%
# 65   33  Andaman & Nicobar Islands          -       -
#
# [66 rows x 4 columns]

# %% [markdown]
# Question-4

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://github.com/")

# %%
explore=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
explore.click()

# %%
trending=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/main/div[1]/nav/div/a[3]")
trending.click()

# %%
Repository_title = []
Description = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']//a"):
        Repository_title.append(i.text)
except NoSuchElementException:
    Repository_title.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']"):
        Description.append(i.text)
except NoSuchElementException:
    Description.append("-")

# %% [markdown]
# Question-5

# %%
driver=webdriver.Chrome()

# %%
driver.get("https:/www.billboard.com/")

# %%
charts=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
charts.click()

# %%
hotsongs=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div/div[2]/span/a")
hotsongs.click()

# %%
Artist_Name =[]
Last_week_rank = []
Peak_rank = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']"):
        Artist_Name.append(i.text)
except NoSuchElementException:
    Artist_Name.append("-")

# %%
TopArtist = pd.DataFrame({})
TopArtist['Artist_Name'] = Artist_Name

TopArtist
# Out:
#                               Artist_Name
# 0                            Taylor Swift
# 1                                Doja Cat
# 2                            Mariah Carey
# 3                                     SZA
# 4    Zach Bryan Featuring Kacey Musgraves
# ..                                    ...
# 391      Riley Green Featuring Luke Combs
# 392         Cardi B & Megan Thee Stallion
# 393                            Luke Bryan
# 394             Drake Featuring 21 Savage
# 395                               Karol G
#
# [396 rows x 1 columns]

# %% [markdown]
# Question-6

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//tbody//tr//td[1]"):
        Book_name.append(i.text)
except NoSuchElementException:
    Book_name.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//tbody//tr//td[3]"):
        Author_name.append(i.text)
except NoSuchElementException:
    Author_name.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//tbody//tr//td[4]"):
        Volumes_sold.append(i.text)
except NoSuchElementException:
    Volumes_sold.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//tbody//tr//td[5]"):
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//tbody//tr//td[1]"):
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append("-")

# %%
Novels = pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#     Book Name            Author Volume sold        Publisher Genre
# 0           1        Brown, Dan   5,094,805       Transworld     1
# 1           2     Rowling, J.K.   4,475,152       Bloomsbury     2
# 2           3     Rowling, J.K.   4,200,654       Bloomsbury     3
# 3           4     Rowling, J.K.   4,179,479       Bloomsbury     4
# 4           5      James, E. L.   3,758,936     Random House     5
# ..        ...               ...         ...              ...   ...
# 195        96    Harris, Robert     807,311     Random House    96
# 196        97     Oliver, Jamie     794,201          Penguin    97
# 197        98  Collins, Suzanne     792,187  Scholastic Ltd.    98
# 198        99      Pelzer, Dave     791,507            Orion    99
# 199       100     Oliver, Jamie     791,095          Penguin   100
#
# [200 rows x 5 columns]

# %% [markdown]
# Question-7

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']//a"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
        Year_span.append(i.text)
except NoSuchElementException:
    Year_span.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']//span[5]"):
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
        Run_time.append(i.text)
except NoSuchElementException:
    Run_time.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append("-")

# %%
TV_Series = pd.DataFrame({})
TV_Series['Name'] = Name
TV_Series['Year_span'] = Year_span
TV_Series['Genre'] = Genre
TV_Series['Run_time'] = Run_time
TV_Series['Ratings'] = Ratings

TV_Series
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things  (2016–2025)    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#      Run_time Ratings
# 0   4,189 min     9.2
# 1      51 min     8.7
# ...

# %% [markdown]
# Question-8

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
dataset=driver.find_element(By.XPATH, "/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]")
dataset.click()

# %%
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

# %%
try:
    for i in driver.find_elements(By.XPATH,"//a[@class='link-hover link text-xl font-semibold']"):
        Dataset_name.append(i.text)
except NoSuchElementException:
    Dataset_name.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='col-span-3 flex items-center gap-2'][2]"):
        Data_type.append(i.text)
except NoSuchElementException:
    Data_type.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//p[@class='truncate'][1]"):
        Task.append(i.text)
except NoSuchElementException:
    Task.append("-")

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='col-span-3 flex items-center gap-2'][1]"):
        Attribute_type.append(i.text)
except NoSuchElementException:
    Attribute_type.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='col-span-3 flex items-center gap-2'][3]"):
        No_of_instances.append(i.text)
except NoSuchElementException:
    No_of_instances.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='col-span-3 flex items-center gap-2'][4]"):
        No_of_attributes.append(i.text)
except NoSuchElementException:
    No_of_attributes.append("-")
    
try:
    for i in driver.find_elements(By.XPATH,"//table//td[3]"):
        Year.append(i.text)
except NoSuchElementException:
    Year.append("-")

# %%
Machinelearning = pd.DataFrame({})
Machinelearning['Dataset_name'] = Dataset_name
Machinelearning['Data_type'] = Data_type
Machinelearning['Task'] = Task 
Machinelearning['Attribute_type'] = Attribute_type 



Machinelearning
# Out:
#                            Dataset_name                  Data_type  \
# 0                                  Iris                    Tabular
# 1                         Heart Disease               Multivariate
# 2                                 Adult               Multivariate
# 3                                  Wine                    Tabular
# 4  Breast Cancer Wisconsin (Diagnostic)               Multivariate
# 5                              Diabetes  Multivariate, Time-Series
# 6                      Dry Bean Dataset               Multivariate
# 7                        Car Evaluation               Multivariate
# 8                          Wine Quality               Multivariate
# 9                        Bank Marketing               Multivariate
#
#                                                 Task  \
# 0  A small classic dataset from Fisher, 1936. One...
# 1  4 databases: Cleveland, Hungary, Switzerland, ...
# 2  Predict whether income exceeds $50K/yr based o...
# ...
